# %% [markdown]
# # BOKA Python Assesment
# Dear applicant,
#
# We have prepared a Python assessment to test your Python knowledge and your problem solving skills.
# It is centered around packages we use on a day-to-day basis. Please make sure you have activated your virtual environment and installed the correct versions of the packages. With the following command you can check if everything works as expected:

# %%
import pandas as pd
import geopandas as gpd
import shapely
import matplotlib.pyplot as plt

print("Pandas version: ", pd.__version__)
print("GeoPandas version: ", gpd.__version__)
print("Shapely version: ", shapely.__version__)
# Out:
# Pandas version:  1.5.3
# GeoPandas version:  0.12.2
# Shapely version:  2.0.1

# %% [markdown]
# ## Section 1 - AIS data
#
# AIS (Automatic Identification System) is the **speed, position and course** data of a ship. It is the mariner's most significant development in navigation safety since the introduction of radar. Its purpose is to help identify ships, assist in target tracking, assist in search and rescue operation, simplify information exchange and provide additional information to assist situational awareness (International Maritime Organization (IMO), A 29/Res.1106)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Boskalis and AIS
# At our Data Science & Engineering department we do a lot of analysis with AIS. So during this assessment we'd like you to get to know our Business a bit better.
#
# We have prepared 3 days of **AIS** data which is located in the `ais` folder.

# %% [markdown]
# ### 1.1 - Read in AIS data
#
# - Please checkout the `ais` data folder and read all the files into 1 single pandas DataFrame
# - The `ReceivedUTC` column is a string format, transform this into a `datetime` format

# %% [markdown]
# ### 1.2 Resample AIS data
# Normally the AIS data is in a 1-3 second frequency. For plotting purposes this is not very handy if you want to have a quick look about what is happening. A common technique to mitigate this problem is resampling.
#
# - Set the `ReceivedUTC` column as the index column
# - Resample the data to an interval of `30 seconds` (tip: pandas has a built in function for this)
# - Think carefully about which operation on the resampler you use

# %% [markdown]
# ### 1.3 Plot results
# Have a look at your DataFrame and see what the results are.
#
# - Plot the `Heading` and `CourseOverGround` in a single figure
# - scatter plot the position of the vessel (`x=Longitude` and `y=Latitude`)

# %% [markdown]
# ## Section 2 - Polygons
#
# This section is about reading in polygons. We will use the `geopandas` package for this.
# In the `polygons/Rotterdam.kml` file  a set of polygons in the Rotterdam region is prepared.
#
# - Use the `fiona` package to read in the kml file
# - Use the following code lines to support the kml driver
#
# ```python
# import fiona
# gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
# ```
#
# - Which Polygons are present in the Rotterdam datafile?
